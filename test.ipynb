# %%
import pandas as pd
import numpy as np
import torch

# %%
data["secondary_labels"].unique()
# Out:
# array(["['']", "['65448', '22976', '476538']", "['compau']", "['65448']",
#        "['65547']", "['22976']", "['soulap1']", "['bubwre1']",
#        "['rinkin1']", "['yectyr1']", "['grekis']", "['trokin']",
#        "['recwoo1', 'trokin', 'rumfly1', 'grekis']", "['rugdov']",
#        "['neocor', 'banana']", "['whtdov']", "['banana']",
#        "['rutjac1', 'paltan1']",
#        "['rutjac1', 'bafibi1', 'banana', 'grekis']", "['bobfly1']",
#        "['socfly1']", "['littin1']", "['sobtyr1']", "['chbant1']",
#        "['yeofly1']", "['greegr']", "['saffin']", "['paltan1']",
#        "['baymac']", "['rtlhum']", "['bobfly1', 'rumfly1', 'cinbec1']",
#        "['plbwoo1']", "['pirfly1']", "['rumfly1']", "['orcpar']",
#        "['trokin', 'grekis']",
#        "['whbant1', 'rebbla1', 'whtdov', 'cinbec1', 'rugdov']",
#        "['pavpig2']", "['whttro1', 'blcjay1', 'trokin']",
#        "['blbwre1', 'crbtan1']", "['yebfly1']", "['yebela1']",
# ...
