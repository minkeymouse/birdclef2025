# %%
import pandas as pd

# %%
df = pd.read_csv("../data/birdclef/DATABASE/train_metadata.csv")
df
# Out:
#                      filename  end_sec  \
# 0          21211/XC934741.ogg      5.0
# 1          21211/XC934741.ogg     10.0
# 2          21211/XC934741.ogg     15.0
# 3          21211/XC934741.ogg     20.0
# 4          21211/XC934741.ogg     25.0
# ...                       ...      ...
# 49413  yelori1/iNat890146.ogg     25.0
# 49414  yelori1/iNat890146.ogg     30.0
# 49415  yelori1/iNat890146.ogg     35.0
# 49416  yelori1/iNat890146.ogg     40.0
# 49417  yelori1/iNat890146.ogg     45.0
#
#                                        mel_path  \
# 0      data/birdclef/DATABASE/mels/39935d66.npy
# 1      data/birdclef/DATABASE/mels/ec98915f.npy
# 2      data/birdclef/DATABASE/mels/360c5bad.npy
# 3      data/birdclef/DATABASE/mels/cb4e083e.npy
# 4      data/birdclef/DATABASE/mels/28c20808.npy
# ...                                         ...
# 49413  data/birdclef/DATABASE/mels/d4734eff.npy
# 49414  data/birdclef/DATABASE/mels/bff5ead5.npy
# 49415  data/birdclef/DATABASE/mels/c6c03334.npy
# ...
